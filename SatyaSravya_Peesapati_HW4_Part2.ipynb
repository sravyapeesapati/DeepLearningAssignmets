# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyapeesapati/DeepLearningAssignmets/blob/main/SatyaSravya_Peesapati_HW4_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/My Drive/butterfly2/data.yaml" epochs=25 imgsz=800 plots=True
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !pip install -q yolov8
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 57.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 22.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# Step 2: Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/My Drive/butterfly2/data.yaml" epochs=25 imgsz=800 plots=True
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 298MB/s]
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
from IPython.display import display, Image

# Correct the file path according to the file location in this environment
file_path = '/content/runs/detect/train/confusion_matrix.png'

# Display the image
display(Image(filename=file_path, width=800))

# %%
file_path = '/content/runs/detect/train/val_batch0_labels.jpg'

# Display the image
display(Image(filename=file_path, width=800))

# %%
file_path = '/content/runs/detect/train/val_batch0_pred.jpg'

# Display the image
display(Image(filename=file_path, width=800))
